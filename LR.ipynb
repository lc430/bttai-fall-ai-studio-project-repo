# %%
# %run data_prep.ipynb

# %%
# Train/test split
from sklearn.calibration import LabelEncoder
from sklearn.discriminant_analysis import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

model = LogisticRegression(class_weight="balanced", max_iter=1000)
model.fit(X_train, y_train)

probabilities = model.predict_proba(X_test)
y_pred = model.predict(X_test)

print("Log Loss:", log_loss(y_test, probabilities))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Log Loss: 0.4217703395900576
# Accuracy: 0.8204861832536879

# %%
# neural networks
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)
nn_model = keras.Sequential()

nn_model.add(keras.layers.Dense(128, input_dim=X_train.shape[1], activation='relu'))
nn_model.add(keras.layers.Dense(64, activation='relu'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ishveenk/bttai-fall-ai-studio-project-repo/LR.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/ishveenk/bttai-fall-ai-studio-project-repo/LR.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # neural networks
# ----> <a href='vscode-notebook-cell:/Users/ishveenk/bttai-fall-ai-studio-project-repo/LR.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/Users/ishveenk/bttai-fall-ai-studio-project-repo/LR.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow import keras
#       <a href='vscode-notebook-cell:/Users/ishveenk/bttai-fall-ai-studio-project-repo/LR.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)
#
# ModuleNotFoundError: No module named 'tensorflow'
